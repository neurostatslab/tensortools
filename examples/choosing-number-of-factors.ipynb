# %%
import tensortools as tt
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# ground truth model
N, R = 100, 3
factors = [np.random.randn(N, R) for _ in range(3)]

# noisy data
sigma = 0.2
data = np.einsum('ir,jr,kr->ijk', *factors) + sigma*np.random.randn(N,N,N)

# %%
# fit models
results = tt.cp_batch_fit(data, range(1,9), replicates=10, tol=1e-7)
# Out:
# Optimizing rank-1 models.
#    10/10 converged, min error = 0.7810, max error = 0.8604, mean error = 0.8176
# Optimizing rank-2 models.
#    10/10 converged, min error = 0.5203, max error = 0.6336, mean error = 0.5530
# Optimizing rank-3 models.
#    10/10 converged, min error = 0.1063, max error = 0.6336, mean error = 0.1591
# Optimizing rank-4 models.
#    10/10 converged, min error = 0.1063, max error = 0.1063, mean error = 0.1063
# Optimizing rank-5 models.
#    10/10 converged, min error = 0.1063, max error = 0.1063, mean error = 0.1063
# Optimizing rank-6 models.
#    10/10 converged, min error = 0.1063, max error = 0.1063, mean error = 0.1063
# Optimizing rank-7 models.
#    10/10 converged, min error = 0.1062, max error = 0.1063, mean error = 0.1063
# Optimizing rank-8 models.
#    10/10 converged, min error = 0.1062, max error = 0.1063, mean error = 0.1063

# %%
tt.plot_scree(results)
# Out:
# (<matplotlib.figure.Figure at 0x105aec080>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x110d27828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112f2c048>], dtype=object))

# %%
from jetpack import breathe

fig, axes = tt.plot_similarity(results, figsize=(8,4))

plt.tight_layout()
plt.show()
