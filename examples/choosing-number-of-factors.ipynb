# %%
import tensortools as tt
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# ground truth model
N, R = 100, 3
factors = [np.random.randn(N, R) for _ in range(3)]

# noisy data
sigma = 0.2
data = np.einsum('ir,jr,kr->ijk', *factors) + sigma*np.random.randn(N,N,N)

# %%
# fit models
results = tt.cp_batch_fit(data, range(1,9), replicates=10)
# Out:
# Optimizing rank-1 models.
#    10/10 converged, min error = 0.8014, max error = 0.8387, mean error = 0.8188
# Optimizing rank-2 models.
#    10/10 converged, min error = 0.5582, max error = 0.6099, mean error = 0.5784
# Optimizing rank-3 models.
#    10/10 converged, min error = 0.1214, max error = 0.1214, mean error = 0.1214
# Optimizing rank-4 models.
#    10/10 converged, min error = 0.1214, max error = 0.1214, mean error = 0.1214
# Optimizing rank-5 models.
#    10/10 converged, min error = 0.1214, max error = 0.1214, mean error = 0.1214
# Optimizing rank-6 models.
#    10/10 converged, min error = 0.1214, max error = 0.1214, mean error = 0.1214
# Optimizing rank-7 models.
#    10/10 converged, min error = 0.1214, max error = 0.1214, mean error = 0.1214
# Optimizing rank-8 models.
#    10/10 converged, min error = 0.1213, max error = 0.1214, mean error = 0.1213

# %%
tt.plot_scree(results)
# Out:
# (<matplotlib.figure.Figure at 0x1126e91d0>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x112757390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11300b2e8>], dtype=object))
