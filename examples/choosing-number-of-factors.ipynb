# %%
import tensortools as tt
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# ground truth model
N, R = 100, 3
factors = [np.random.randn(N, R) for _ in range(3)]

# noisy data
sigma = 0.2
data = np.einsum('ir,jr,kr->ijk', *factors) + sigma*np.random.randn(N,N,N)

# %%
# fit models
results = tt.cp_batch_fit(data, range(1,9), replicates=10, tol=1e-7)
# Out:
# Optimizing rank-1 models.
#    10/10 converged, min error = 0.7754, max error = 0.8388, mean error = 0.8246
# Optimizing rank-2 models.
#    10/10 converged, min error = 0.5463, max error = 0.6337, mean error = 0.5780
# Optimizing rank-3 models.
#    10/10 converged, min error = 0.1071, max error = 0.5601, mean error = 0.1524
# Optimizing rank-4 models.
#    10/10 converged, min error = 0.1070, max error = 0.1071, mean error = 0.1071
# Optimizing rank-5 models.
#    10/10 converged, min error = 0.1070, max error = 0.1070, mean error = 0.1070
# Optimizing rank-6 models.
#    10/10 converged, min error = 0.1070, max error = 0.1070, mean error = 0.1070
# Optimizing rank-7 models.
#    10/10 converged, min error = 0.1070, max error = 0.1070, mean error = 0.1070
# Optimizing rank-8 models.
#    10/10 converged, min error = 0.1070, max error = 0.1070, mean error = 0.1070

# %%
tt.plot_scree(results)
# Out:
# (<matplotlib.figure.Figure at 0x1059b00b8>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x1103a8860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1125e9fd0>], dtype=object))

# %%
from jetpack import breathe

fig, axes = tt.plot_similarity(results, figsize=(8,4))

plt.tight_layout()
plt.show()
